# %%
# %run function_test.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/Documents/GitHub/GUI-in-Python-/pyClasses/function_test.py:34
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "546c55aa-9f26-4ffe-bbde-2085b32f5aa3",
#       7    "metadata": {},
#       8    "outputs": [
#       9     {
#      10      "ename": "NameError",
#      11      "evalue": "name 'null' is not defined",
#      12      "output_type": "error",
#      13      "traceback": [
#      14       "\u001b---------------------------------------------------------------------------\u001b",
#      15       "\u001bNameError\u001b                                 Traceback (most recent call last)",
# ...
